# %%
import sys
# !"{sys.executable}" -m pip install pandas
!"{sys.executable}" -m pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.8-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.8 idna-3.3 requests-2.26.0 urllib3-1.26.7
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\jlo.CLFPNET\repos\python\jupyterenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'50',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6b39fd31-bb20-4fb0-83a3-8a24138ced6e',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2021-11-26T13:59:57.325Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 7764}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 8363, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18883612, 'total_supply': 18883612, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-11-26T13:59:02.000Z', 'quote': {'USD': {'price': 54670.1072933543, 'volume_24h': 42854148154.01004, 'volume_change_24h': 22.1715, 'percent_change_1h': 0.68146047, 'percent_change_24h': -6.65945739, 'percent_change_7d': -5.14166, 'percent_change_30d': -7.4168944, 'percent_change_60d': 25.54115709, 'percent_change_90d': 12.14008396, 'market_cap': 1032369094126.0728, 'market_cap_dominance': 41.9434, 'fully_diluted_market_cap': 1148072253160.44, 'last_updated': '2021-11-26T13:59:02.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 4704, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum-ecosystem', 'binance-smart-chain', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kinetic-capital', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': None, 'circulating_supply': 118496693.749, 'total_supply': 118496693.749, 'platform': None, 'cmc_rank': 2, 'last_updated': '2021-11-26T13:59:02.000Z', 'quote': {'USD': {'price': 4092.7997994641046, 'volume_24h': 26008666452.835854, 'volume_change_24h': 31.48, 'percent_change_1h': 1.10111584, 'percent_change_24h': -8.21388744, 'percent_change_7d': -2.73117135, 'percent_change_30d': 2.39994433, 'percent_change_60d': 33.15789308, 'percent_change_90d': 26.67952775, 'market_cap': 484983244413.0666, 'market_cap_dominance': 19.704, 'fully_diluted_market_cap': 484983244413.07, 'last_updated': '2021-11-26T13:59:02.000Z'}}}, {'id': 1839, 'name': 'Binance Coin', 'symbol': 'BNB', 'slug': 'binance-coin', 'num_market_pairs': 560, 'date_added': '2017-07-25T00:00:00.000Z', 'tags': ['marketplace', 'centralized-exchange', 'payments', 'smart-contracts', 'binance-smart-chain', 'alameda-research-portfolio', 'multicoin-capital-portfolio'], 'max_supply': 166801148, 'circulating_supply': 166801148, 'total_supply': 166801148, 'platform': None, 'cmc_rank': 3, 'last_updated': '2021-11-26T13:58:12.000Z', 'quote': {'USD': {'price': 593.5762012757791, 'volume_24h': 4323288193.49834, 'volume_change_24h': 38.5864, 'percent_change_1h': 1.4070701, 'percent_change_24h': -6.02840598, 'percent_change_7d': 3.22210016, 'percent_change_30d': 30.07007062, 'percent_change_60d': 70.59998089, 'percent_change_90d': 21.8193565, 'market_cap': 99009191798.27902, 'market_cap_do ...

# %%
latest_listings_df = pd.DataFrame.from_dict(data['data'])

# %%
latest_listings_df.columns
# Out:
# Index(['id', 'name', 'symbol', 'slug', 'num_market_pairs', 'date_added',
#        'tags', 'max_supply', 'circulating_supply', 'total_supply', 'platform',
#        'cmc_rank', 'last_updated', 'quote'],
#       dtype='object')

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/historical'
parameters = {
  'symbols':'1',
  'limit':'50',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6b39fd31-bb20-4fb0-83a3-8a24138ced6e',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
